# %% [markdown]
# **Visualize Function**

# %%
def visualize(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')
    #data=pd.read_csv(filepath_or_buffer=filename)
    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)
    
    axes1.set_ylabel('average')
    axes1.set_xlabel('Feature#')
    axes1.plot(numpy.mean(data, axis=0))
    
    
    axes2.set_ylabel('Max')
    axes2.set_xlabel('Feature#')
    axes2.plot(numpy.max(data, axis=0))
    
    axes3.set_ylabel('Min')
    axes3.set_xlabel('Feature#')
    axes3.plot(numpy.min(data, axis=0))
    
   
    
    fig.tight_layout()
    matplotlib.pyplot.show()

# %% [markdown]
# **Identify_Issues function**

# %%
def identify_issues(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')
   # data=pd.read_csv(filepath_or_buffer=filename)
    
    if numpy.max(data, axis=0)[0] == 0 and numpy.max(data, axis=0)[20] == 20:
        print('I doubt the integrity of this dataset\n')
        
    elif numpy.min(data,axis=0)[0]==0 and numpy.min(data, axis=0)[20] == 0:
        print('Why is this happening\n?')
    
    else: 
        print('Dataset looks good\n')

# %%
import glob
import numpy 
import matplotlib
import matplotlib.pyplot 

dataset = sorted(glob.glob(r'C:\Users\hp\Downloads\data*.csv'))

for datasets in dataset[:4]:
    print(datasets)
    visualize(datasets)
    identify_issues(datasets)
# Out:
# C:\Users\hp\Downloads\data-01.csv
# I doubt the integrity of this dataset
#
# C:\Users\hp\Downloads\data-02.csv
# Dataset looks good
#
# C:\Users\hp\Downloads\data-03.csv
# Why is this happening?
#
# C:\Users\hp\Downloads\data-04.csv
# I doubt the integrity of this dataset
